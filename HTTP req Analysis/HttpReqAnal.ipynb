# %%
import json
from haralyzer import HarParser, HarPage

# %%
har_parser = HarParser.from_file("amazon.nl02.har")

# %%
for page in har_parser.pages:
    for entry in page.entries:     
        for cook in entry.request.cookies:
#             if ('cookie' in header['name']):
#                 print(entry.response.headers)
                print(cook)
        print("***************************************************")
#         header_names = [ header['name'] for header in entry.response.headers]
#         if 'set-cookie' in header_names:
#             print(header_names)
# Out:
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741409740', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:49.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741409740', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:49.000Z', 'httpOnly': False, 'secure': False}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741409740', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:49.000Z', 'httpOnly': False, 'secure': False}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741409740', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:49.000Z', 'httpOnly': False, 'secure': False}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741412187&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:52.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741412187&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:52.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741412187&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:52.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-TQ4MQKPADMYEF48V4G16|1677741409740&t:1677741412187&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:52.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:CA68N5360GHVTZHPRRN4+s-TQ4MQKPADMYEF48V4G16|1677741416821&t:1677741416821&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:56.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:CA68N5360GHVTZHPRRN4+s-TQ4MQKPADMYEF48V4G16|1677741416821&t:1677741416821&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:56.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': '"L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE="', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:50.706Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:CA68N5360GHVTZHPRRN4+s-TQ4MQKPADMYEF48V4G16|1677741416821&t:1677741416821&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:56.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:CA68N5360GHVTZHPRRN4+s-TQ4MQKPADMYEF48V4G16|1677741416821&t:1677741416821&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:16:56.000Z', 'httpOnly': False, 'secure': False}
# ...
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# {'name': 'csm-hit', 'value': 'tb:s-212SZXGRQ9RFSYA1Z0PH|1677741424224&t:1677741426547&adb:adblk_no', 'path': '/', 'domain': 'www.amazon.nl', 'expires': '2024-02-15T07:17:06.000Z', 'httpOnly': False, 'secure': False}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************
# {'name': 'session-id', 'value': '260-2043990-7624917', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-id-time', 'value': '2082787201l', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'i18n-prefs', 'value': 'EUR', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:35.277Z', 'httpOnly': False, 'secure': False}
# {'name': 'ubid-acbnl', 'value': '260-1928997-7640813', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-03-01T07:16:49.394Z', 'httpOnly': False, 'secure': True}
# {'name': 'lc-acbnl', 'value': 'nl_NL', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': False, 'secure': True}
# {'name': 'session-token', 'value': 'L8pJaDUdmjmm6ThaK+Xh8FqdyF1uF5uJyQ4zjoO8UBaqjd+nMW2pTqn0VvXnwKvtAe818zPhlWGJy9dpWFi8cTtsblTpX/igX7KjmZTG/qMRj6aVQta9YXBVeGXOoX6C+fhE1op6UOgYp/iY+aBho/ymZ1LDur9gEMqUqGQGeDmdyC/DF725h0H3FB5fBu3DpaarlknyYAyZeR3iNUnPltFUiNSSl4Qoc6/mdhHdIRE=', 'path': '/', 'domain': '.amazon.nl', 'expires': '2024-04-05T07:16:58.634Z', 'httpOnly': True, 'secure': True}
# ***************************************************

# %% [markdown]
# Extract the total count of requests.

# %%
num_reqs = 0
for page in har_parser.pages:
    num_reqs = num_reqs + len(page.entries)
        
print("number of requests totals to:", num_reqs)
# Out:
# number of requests totals to: 481

# %% [markdown]
# Number of requests containing cookies

# %%
num_requests_w_cookies = 0
for page in har_parser.pages:
    for entry in page.entries:
        if entry.request.cookies:
            num_requests_w_cookies = num_requests_w_cookies +1
print("Number of requests containing cookies is: ", num_requests_w_cookies)
# Out:
# Number of requests containing cookies is:  117

# %% [markdown]
# Number of responses containing cookies

# %%
num_responses_w_cookies = 0
for page in har_parser.pages:
    for entry in page.entries:
        header_names = [ header['name'] for header in entry.response.headers]
        if 'set-cookie' in header_names:
            num_responses_w_cookies = num_responses_w_cookies +1
print("Number of responses containing cookies is: ", num_responses_w_cookies)
# Out:
# Number of responses containing cookies is:  3

# %% [markdown]
# ● third_party_domains: list of distinct third-party domains (eTLD+1)

# %% [markdown]
# ● cookie_domains: list of distinct cookie domain attributes (using the cookies field)

# %%
cookie_domains = []
for page in har_parser.pages:
    for entry in page.entries:
        domains = [cookie['domain'] for cookie in entry.request.cookies]
        [j for i in domains for j in i]
        print(domains)
#         print(set(domains))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# []
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', 'www.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']
# ['.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl', '.amazon.nl']

# %% [markdown]
# ● xorigin_cookie_domains: list of cookie domains set via HTTP response headers, with
# SameSite=None, and lifespan >= 90 days

# %% [markdown]
# ● server_countries: list of distinct server countries (using the serverIPAddress field and the
# geolocation databases linked below)

# %% [markdown]
# ● requests: a list of dictionaries, where each dictionary contains the following
# request/response details:
# ○ request_domain: String; e.g. example.com
# ○ server_country: String; e.g. Germany; “unknown” if server IP is unavailable
# ○ num_request_cookies: Integer
# ○ num_response_cookies: Integer
# ○ is_tracker: Boolean; whether the request hostname or domain is listed in EasyList
# or EasyPrivacy “just domains” blocklists
# ○ url_first_128_char: String; the first 128 characters of the URL; e.g.
# https://example.com/pixel.gif
